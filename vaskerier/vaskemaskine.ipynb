# %%
import pandas as pd
import re

path = '/Users/alhu/Data/Konverteringsdata/Til Upload/Regnskabstekster/Vaskeri/Raw/19062025_Faciliteter_Alle.xlsx'
df = pd.read_excel(path)

import re

def extract_first_number(val):
    if pd.isna(val):
        return None
    s = str(val)
    m = re.search(r"\b([0-9]+)\b", s)
    return int(m.group(1)) if m else None

df_filtered = df[df['SAP Beskrivelse'].isin(['Vaskemaskine'])]

df_filtered['Afdeling'] = df_filtered['Lejemålets beliggenhed - Ej medtages'].apply(extract_first_number)

df_filtered.head()
# Out:
#   Medtages OBS! Bygning/Lejemål  Ej medtages          Lejemåls nr.  \
# 0  Ejendom              Bygning  Grundstykke  Arealpool/udlejnEnh.
# 1    50000                    1          NaN                   NaN
# 2    50000                    1          NaN                   NaN
# 3    50000                    1          NaN                   NaN
# 4    50000                    1          NaN                     1
#
#                 Lejemålets beliggenhed - Ej medtages SAP Facilitets nr.  \
# 0                                         Betegnelse          Kendetegn
# 1            10 : Lyngby Hovedgade 95A-C 2800 Lyngby                 12
# 2            10 : Lyngby Hovedgade 95A-C 2800 Lyngby                 15
# 3            10 : Lyngby Hovedgade 95A-C 2800 Lyngby                140
# 4  10, Lyngby Hovedgade 95A, st. tv. / 2800 Konge...                 50
#
#          SAP Beskrivelse       Unnamed: 7  DAB nr.  DAB Beskrivelse  Afdeling
# 0    Facilitetskendetegn       Undersøges  DAB nr.  DAB Beskrivelse       NaN
# 1  Husdyrhold (hund/kat)  KLI / MDG / TNE      NaN              NaN      10.0
# 2                Vaskeri  KLI / MDG / TNE      NaN              NaN      10.0
# 3               Kabel TV        KLI / MDG      NaN              NaN      10.0
# 4            Eget køkken              NaN       10      Eget køkken      10.0
